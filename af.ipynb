# %%
#Important module and library  to run the program 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("aff.csv") #df for dataframe,read the data from the csv data file
df
# Out:
#     date  affected
# 0      1         3
# 1      2         0
# 2      3         0
# 3      4         0
# 4      5         0
# ..   ...       ...
# 69    70      1602
# 70    71      1251
# 71    72      1617
# 72    73      1773
# 73    74      1694
#
# [74 rows x 2 columns]

# %%
# For the data visualization 
# %matplotlib inline
plt.xlabel('From 8th March to 22th May')
plt.ylabel('Number of newly Affected People')
plt.scatter(df.date, df.affected)

# %%
X = df[['date']] #since x have to be two dimentional or 2D array. So [[]]

# %%
y = df['affected']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10) 
#if you use "random_state=10" then the smaple will be same all the time

# %%
X_train
# Out:
#     date
# 3      4
# 71    72
# 73    74
# 35    36
# 34    35
# 2      3
# 66    67
# 5      6
# 11    12
# 13    14
# 50    51
# 1      2
# 8      9
# 72    73
# 21    22
# 53    54
# 62    63
# 47    48
# 65    66
# 14    15
# 16    17
# 46    47
# 19    20
# 37    38
# 30    31
# 56    57
# 33    34
# 40    41
# 36    37
# 9     10
# 43    44
# 63    64
# 27    28
# 32    33
# 44    45
# 25    26
# 67    68
# 15    16
# 31    32
# 55    56
# 4      5
# 52    53
# 61    62
# 70    71
# 41    42
# 26    27
# 57    58
# 17    18
# 58    59
# 22    23
# 7      8
# 64    65
# 10    11
# 68    69
# 45    46
# 38    39
# 29    30
# 24    25
# 39    40

# %%
X_test
# Out:
#     date
# 28    29
# 18    19
# 51    52
# 69    70
# 12    13
# 59    60
# 42    43
# 49    50
# 6      7
# 54    55
# 48    49
# 0      1
# 60    61
# 20    21
# 23    24

# %%
y_train
# Out:
# 3        0
# 71    1617
# 73    1694
# 35     182
# 34     139
# 2        0
# 66    1202
# 5        0
# 11       3
# 13       3
# 50     641
# 1        0
# 8        2
# 72    1773
# 21       1
# 53     552
# 62    1034
# 47     418
# 65    1041
# 14       6
# 16       0
# 46     309
# 19       0
# 37     219
# 30      54
# 56     786
# 33      58
# 40     312
# 36     209
# 9        4
# 43     390
# 63     969
# 27      18
# 32      94
# 44     414
# 25       5
# 67     930
# 15       6
# 31     112
# 55     688
# 4        0
# 52     571
# 61     887
# 70    1251
# 41     492
# 26       9
# 57     790
# 17       5
# 58     706
# 22       2
# 7        3
# 64    1162
# 10       3
# 68    1273
# 45     503
# 38     341
# 29      41
# 24       2
# 39     306
# Name: affected, dtype: int64

# %%
y_test
# Out:
# 28      35
# 18       4
# 51     564
# 69    1602
# 12       4
# 59     709
# 42     434
# 49     549
# 6        2
# 54     665
# 48     497
# 0        3
# 60     636
# 20       0
# 23       3
# Name: affected, dtype: int64

# %%
# use the regression model for the dataset
reg=LinearRegression() #creat the object for the regression
reg.fit(X_train, y_train)  #pass the data through the model, reg.fit(1st argument, 2nd argument);
            #1st argument have to be two dimentional or 2D array
            #2nd argument have to be y axis or the output, since y=mx+c
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict(X_test)
# Out:
# array([ 231.1840868 ,   23.49508917,  708.86878134, 1082.70897707,
#        -101.11830941,  875.01997945,  521.94868348,  667.33098182,
#        -225.73170799,  771.17548063,  646.56208205, -350.34510657,
#         895.78887921,   65.03288869,  127.33958798])

# %%
y_test
# Out:
# 28      35
# 18       4
# 51     564
# 69    1602
# 12       4
# 59     709
# 42     434
# 49     549
# 6        2
# 54     665
# 48     497
# 0        3
# 60     636
# 20       0
# 23       3
# Name: affected, dtype: int64

# %%
#We will find the accuracy of this model(our model was liner regression model) for our dataset
reg.score(X_test, y_test)
# Out:
# 0.7545530743720397

# %%
# Give any unknown number,to know the affected people
reg.predict([[98]])
# Out:
# array([1664.23817044])

# %%
#Simple user interface to run our model the model
x=input('To know the affected people,Enter the date you want to know : ')

import numpy as np 
array = np.array(x) #input converted into 1 dimentional array
fvalu = array.astype(np.float) # 1 dimentional array into 1 dimentional float array
fvalu_2D=([[fvalu]]) # 1 dimentional array to 2 dimentional array
#print(fvalu_2D)

my_prediction=reg.predict(fvalu_2D)
#print(my_prediction)


#convert vector into scalar using below two lines
affected=np.array(my_prediction) 
affected=affected.item()

print('So',x,' th day the number of affected people =',affected ,' Person')
# Out:
# To know the affected people,Enter the date you want to know : 75
# So 75  th day the number of affected people = 1186.5534758889698  Person
